# %% [markdown]
# # Local RAG with Ollama and Weaviate

# %% [markdown]
# ## Setup
# 1. Download and install Ollama for your operating system: https://ollama.com/download
# 2. `pip` install the Python library to generate vector embeddings from the model  with `pip install ollama`. (REST API or JavaScript library also available)

# %%
# !pip install ollama
# !pip install -U weaviate-client
# Out:
# Collecting ollama
#   Using cached ollama-0.4.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: httpx<0.29,>=0.27 in ./venv310/lib/python3.10/site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in ./venv310/lib/python3.10/site-packages (from ollama) (2.11.5)
# Requirement already satisfied: idna in ./venv310/lib/python3.10/site-packages (from httpx<0.29,>=0.27->ollama) (3.10)
# Requirement already satisfied: httpcore==1.* in ./venv310/lib/python3.10/site-packages (from httpx<0.29,>=0.27->ollama) (1.0.9)
# Requirement already satisfied: anyio in ./venv310/lib/python3.10/site-packages (from httpx<0.29,>=0.27->ollama) (4.9.0)
# Requirement already satisfied: certifi in ./venv310/lib/python3.10/site-packages (from httpx<0.29,>=0.27->ollama) (2025.4.26)
# Requirement already satisfied: h11>=0.16 in ./venv310/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.29,>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.4.1)
# Requirement already satisfied: pydantic-core==2.33.2 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.33.2)
# Requirement already satisfied: sniffio>=1.1 in ./venv310/lib/python3.10/site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv310/lib/python3.10/site-packages (from anyio->httpx<0.29,>=0.27->ollama) (1.3.0)
# Installing collected packages: ollama
# Successfully installed ollama-0.4.8
# WARNING: You are using pip version 20.3.3; however, version 25.1.1 is available.
# You should consider upgrading via the '/home/cdchushig/repos_frescos/easy-local-rag/venv310/bin/python -m pip install --upgrade pip' command.
# Collecting weaviate-client
#   Downloading weaviate_client-4.14.4-py3-none-any.whl (437 kB)
#      |████████████████████████████████| 437 kB 153 kB/s eta 0:00:01
# Requirement already satisfied: httpx<0.29.0,>=0.26.0 in ./venv310/lib/python3.10/site-packages (from weaviate-client) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.8.0 in ./venv310/lib/python3.10/site-packages (from weaviate-client) (2.11.5)
# Collecting validators==0.34.0
#   Downloading validators-0.34.0-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 116 kB/s eta 0:00:01
# Collecting authlib<1.3.2,>=1.2.1
#   Downloading Authlib-1.3.1-py2.py3-none-any.whl (223 kB)
#      |████████████████████████████████| 223 kB 67 kB/s eta 0:00:01
# Collecting deprecation<3.0.0,>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: packaging in ./venv310/lib/python3.10/site-packages (from deprecation<3.0.0,>=2.1.0->weaviate-client) (25.0)
# Collecting grpcio<2.0.0,>=1.66.2
#   Using cached grpcio-1.71.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Collecting grpcio-health-checking<2.0.0,>=1.66.2
#   Downloading grpcio_health_checking-1.71.0-py3-none-any.whl (18 kB)
# Collecting grpcio-tools<2.0.0,>=1.66.2
#   Downloading grpcio_tools-1.71.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 23 kB/s eta 0:00:016
# Requirement already satisfied: setuptools in ./venv310/lib/python3.10/site-packages (from grpcio-tools<2.0.0,>=1.66.2->weaviate-client) (51.3.3)
# Requirement already satisfied: certifi in ./venv310/lib/python3.10/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (2025.4.26)
# Requirement already satisfied: anyio in ./venv310/lib/python3.10/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (4.9.0)
# Requirement already satisfied: idna in ./venv310/lib/python3.10/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (3.10)
# Requirement already satisfied: httpcore==1.* in ./venv310/lib/python3.10/site-packages (from httpx<0.29.0,>=0.26.0->weaviate-client) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./venv310/lib/python3.10/site-packages (from httpcore==1.*->httpx<0.29.0,>=0.26.0->weaviate-client) (0.16.0)
# Collecting protobuf<6.0dev,>=5.26.1
#   Using cached protobuf-5.29.4-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (0.4.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (4.13.2)
# Requirement already satisfied: pydantic-core==2.33.2 in ./venv310/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.8.0->weaviate-client) (2.33.2)
# Requirement already satisfied: sniffio>=1.1 in ./venv310/lib/python3.10/site-packages (from anyio->httpx<0.29.0,>=0.26.0->weaviate-client) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./venv310/lib/python3.10/site-packages (from anyio->httpx<0.29.0,>=0.26.0->weaviate-client) (1.3.0)
# Collecting cryptography
#   Downloading cryptography-45.0.3-cp37-abi3-manylinux_2_28_x86_64.whl (4.5 MB)
#      |████████████████████████████████| 4.5 MB 140 kB/s eta 0:00:01
# Requirement already satisfied: cffi>=1.14 in ./venv310/lib/python3.10/site-packages (from cryptography->authlib<1.3.2,>=1.2.1->weaviate-client) (1.17.1)
# Requirement already satisfied: pycparser in ./venv310/lib/python3.10/site-packages (from cffi>=1.14->cryptography->authlib<1.3.2,>=1.2.1->weaviate-client) (2.22)
# Installing collected packages: protobuf, grpcio, cryptography, validators, grpcio-tools, grpcio-health-checking, deprecation, authlib, weaviate-client
# Successfully installed authlib-1.3.1 cryptography-45.0.3 deprecation-2.1.0 grpcio-1.71.0 grpcio-health-checking-1.71.0 grpcio-tools-1.71.0 protobuf-5.29.4 validators-0.34.0 weaviate-client-4.14.4
# WARNING: You are using pip version 20.3.3; however, version 25.1.1 is available.
# You should consider upgrading via the '/home/cdchushig/repos_frescos/easy-local-rag/venv310/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# 3. Pull relevant LLM and [embedding model](https://ollama.com/blog/embedding-models)

# %%
# ollama pull llama2
# ollama pull all-minilm # mxbai-embed-large

# %% [markdown]
# 4. Optional: Test if it works. Run in your terminal: ollama run llama2

# %%
import ollama
response = ollama.chat(model='llama2', messages=[
  {
    'role': 'user',
    'content': 'Why is the sky blue?',
  },
])
print(response['message']['content'])
# Out:
# The sky appears blue because of a phenomenon called Rayleigh scattering, which occurs when sunlight travels through the Earth's atmosphere. When sunlight enters the atmosphere, it encounters tiny molecules of gases such as nitrogen and oxygen. These molecules absorb some of the sunlight and scatter the rest in all directions.
#
# The shorter wavelengths of light, such as blue and violet, are scattered more than the longer wavelengths, such as red and orange. This is known as Rayleigh scattering, named after the British physicist Lord Rayleigh, who first described the phenomenon in the late 19th century.
#
# As a result of this scattering, the blue light is dispersed throughout the atmosphere, giving the sky its blue appearance. The farther away from the sun an observer is, the more blue the sky appears, as the scattered light has to travel longer distances through the atmosphere, where it is scattered even more. This is why the sky can appear a deep blue at twilight or during sunrise and sunset, when the sun is low on the horizon.
#
# It's worth noting that the exact shade of blue can vary depending on factors such as the amount of air pollution, dust, and water vapor in the atmosphere, which can affect the amount of scattering that occurs. However, Rayleigh scattering is the primary cause of the blue color of the sky that we see in everyday life.

# %%
ollama.embeddings(model="llama2", 
                  prompt= "Llamas are members of the camelid family meaning they're pretty closely related to vicuñas and camels")

# %% [markdown]
# ## How to Setup a Local Vector Database Instance with Docker
#
# In a local RAG pipeline, you want to host your vector database locally as well. We will use an instance of the open source Weaviate vector database locally with Docker.
#
# - Step 1: Download and install Docker
# - Step 2: Start up the Docker container with a Weaviate instance. You can run the following command from a terminal to start up a Weaviate instance from the default Docker image.
#   docker run -p 8080:8080 -p 50051:50051 cr.weaviate.io/semitechnologies/weaviate:1.24.8
# - Step 3: Install the Weaviate Python client. Since we’re implementing the RAG pipeline in Python, you will need to pip install:
#   pip install -U weaviate-client

# %% [markdown]
# ## Step 1: Generate embeddings

# %%
documents = [
  "Llamas are members of the camelid family meaning they're pretty closely related to vicuñas and camels",
  "Llamas were first domesticated and used as pack animals 4,000 to 5,000 years ago in the Peruvian highlands",
  "Llamas can grow as much as 6 feet tall though the average llama between 5 feet 6 inches and 5 feet 9 inches tall",
  "Llamas weigh between 280 and 450 pounds and can carry 25 to 30 percent of their body weight",
  "Llamas are vegetarians and have very efficient digestive systems",
  "Llamas live to be about 20 years old, though some only live for 15 years and others live to be 30 years old",
]

# %%
import weaviate
import weaviate.classes as wvc
from weaviate.classes.config import Property, DataType

# %%
client = weaviate.connect_to_embedded()
print(client.is_ready())
# Out:
# {"action":"startup","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","default_vectorizer_module":"none","level":"info","msg":"the default vectorizer modules is set to \"none\", as a result all new schema classes without an explicit vectorizer setting, will use this vectorizer","time":"2025-05-26T10:32:50+02:00"}
# {"action":"startup","auto_schema_enabled":true,"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"auto schema enabled setting is set to \"true\"","time":"2025-05-26T10:32:50+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"No resource limits set, weaviate will use all available memory and CPU. To limit resources, set LIMIT_RESOURCES=true","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"module offload-s3 is enabled","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"warning","msg":"Multiple vector spaces are present, GraphQL Explore and REST API list objects endpoint module include params has been disabled as a result.","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"open cluster service","servers":{"Embedded_at_8079":57859},"time":"2025-05-26T10:32:51+02:00"}
# {"address":"192.168.1.23:57860","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"starting cloud rpc server ...","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"starting raft sub-system ...","time":"2025-05-26T10:32:51+02:00"}
# {"address":"192.168.1.23:57859","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"tcp transport","tcpMaxPool":3,"tcpTimeout":10000000000,"time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"loading local db","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"local DB successfully loaded","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"schema manager loaded","n":0,"time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","metadata_only_voters":false,"msg":"construct a new raft node","name":"Embedded_at_8079","time":"2025-05-26T10:32:51+02:00"}
# {"action":"raft","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","index":0,"level":"info","msg":"raft initial configuration","servers":"[[]]","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","last_snapshot_index":0,"last_store_applied_index_on_start":0,"level":"info","msg":"raft node constructed","raft_applied_index":0,"raft_last_index":0,"time":"2025-05-26T10:32:51+02:00"}
# {"action":"raft","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","follower":{},"leader-address":"","leader-id":"","level":"info","msg":"raft entering follower state","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","hasState":false,"level":"info","msg":"raft init","time":"2025-05-26T10:32:51+02:00"}
# {"action":"read_disk_use","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"warning","msg":"disk usage currently at 81.25%, threshold set to 80.00%","path":"/home/cdchushig/.local/share/weaviate","time":"2025-05-26T10:32:51+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"attempting to join","remoteNodes":["192.168.1.23:57859"],"time":"2025-05-26T10:32:52+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"attempted to join and failed","remoteNode":"192.168.1.23:57859","status":8,"time":"2025-05-26T10:32:52+02:00"}
# {"action":"bootstrap","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","error":"could not join a cluster from [192.168.1.23:57859]","level":"warning","msg":"failed to join cluster","servers":["192.168.1.23:57859"],"time":"2025-05-26T10:32:52+02:00","voter":true}
# {"action":"bootstrap","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","candidates":[{"Suffrage":0,"ID":"Embedded_at_8079","Address":"192.168.1.23:57859"}],"level":"info","msg":"starting cluster bootstrapping","time":"2025-05-26T10:32:52+02:00"}
# {"action":"bootstrap","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"notified peers this node is ready to join as voter","servers":["192.168.1.23:57859"],"time":"2025-05-26T10:32:52+02:00"}
# {"action":"raft","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","last-leader-addr":"","last-leader-id":"","level":"warning","msg":"raft heartbeat timeout reached, starting election","time":"2025-05-26T10:32:52+02:00"}
# {"action":"raft","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"raft entering candidate state","node":{},"term":2,"time":"2025-05-26T10:32:52+02:00"}
# {"action":"raft","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"raft pre-vote successful, starting election","refused":0,"tally":1,"term":2,"time":"2025-05-26T10:32:52+02:00","votesNeeded":1}
# {"action":"raft","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"raft election won","tally":1,"term":2,"time":"2025-05-26T10:32:52+02:00"}
# {"action":"raft","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","leader":{},"level":"info","msg":"raft entering leader state","time":"2025-05-26T10:32:52+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","docker_image_tag":"localhost","level":"info","msg":"configured versions","server_version":"1.26.6","time":"2025-05-26T10:32:53+02:00"}
# {"address":"192.168.1.23:57859","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"current Leader","time":"2025-05-26T10:32:53+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"starting migration from old schema","time":"2025-05-26T10:32:53+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"legacy schema is empty, nothing to migrate","time":"2025-05-26T10:32:53+02:00"}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"migration from the old schema has been successfully completed","time":"2025-05-26T10:32:53+02:00"}
# {"action":"grpc_startup","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"grpc server listening at [::]:50050","time":"2025-05-26T10:32:53+02:00"}
# {"action":"restapi_management","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","docker_image_tag":"localhost","level":"info","msg":"Serving weaviate at http://127.0.0.1:8079","time":"2025-05-26T10:32:53+02:00"}
# {"action":"bootstrap","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"node reporting ready, exiting bootstrap process","time":"2025-05-26T10:32:53+02:00"}
# {"action":"telemetry_push","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"telemetry started","payload":"\u0026{MachineID:e5ab2c61-3e56-4859-b4a9-84721810d49e Type:INIT Version:1.26.6 NumObjects:0 OS:linux Arch:amd64 UsedModules:[]}","time":"2025-05-26T10:32:54+02:00"}
# True

# %%
collection_name = "docs"

if client.collections.exists(collection_name):
    client.collections.delete(collection_name)

collection = client.collections.create(
    collection_name,
    properties=[
        Property(name="text", data_type=DataType.TEXT),
    ],
)
# Out:
# /home/cdchushig/repos_frescos/easy-local-rag/venv310/lib/python3.10/site-packages/weaviate/collections/classes/config.py:1963: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   for cls_field in self.model_fields:
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"warning","msg":"prop len tracker file /home/cdchushig/.local/share/weaviate/docs/pt13JkrNX0RY/proplengths does not exist, creating new tracker","time":"2025-05-26T10:33:07+02:00"}
# {"action":"hnsw_prefill_cache_async","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"not waiting for vector cache prefill, running in background","time":"2025-05-26T10:33:07+02:00","wait_for_cache_prefill":false}
# {"build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"info","msg":"Created shard docs_pt13JkrNX0RY in 7.13646ms","time":"2025-05-26T10:33:07+02:00"}
# {"action":"hnsw_vector_cache_prefill","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","count":1000,"index_id":"main","level":"info","limit":1000000000000,"msg":"prefilled vector cache","time":"2025-05-26T10:33:07+02:00","took":305015}
# {"action":"read_disk_use","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"warning","msg":"disk usage currently at 81.25%, threshold set to 80.00%","path":"/home/cdchushig/.local/share/weaviate","time":"2025-05-26T10:33:22+02:00"}

# %%
import ollama

# store each document in a vector embedding database
with collection.batch.dynamic() as batch:
  for i, d in enumerate(documents):
    response = ollama.embeddings(model="llama2", prompt=d)
    embedding = response["embedding"]
    batch.add_object(
        properties = {"text" : d},
        vector = embedding,
    )

# %%
collection.query.fetch_objects(limit=1, include_vector=True)
# Out:
# QueryReturn(objects=[Object(uuid=_WeaviateUUIDInt('1ac39626-dde0-4c50-8c72-72e823b427d7'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'text': 'Llamas were first domesticated and used as pack animals 4,000 to 5,000 years ago in the Peruvian highlands'}, references=None, vector={'default': [0.7867321372032166, -1.3258379697799683, 2.0011348724365234, -0.05945054814219475, -3.0877368450164795, -1.0692099332809448, 0.9505770206451416, -0.7436917424201965, 0.6250582933425903, 0.6546383500099182, -0.9666812419891357, -2.1725523471832275, -4.04159688949585, 2.2918717861175537, -0.5780858397483826, -1.152021884918213, 1.0969030857086182, 1.0516606569290161, 0.7185672521591187, -2.7123992443084717, 0.8996108770370483, -2.7089102268218994, 1.5572906732559204, -0.4008062481880188, 0.2305132895708084, 0.5275524854660034, 0.5864274501800537, 0.11376510560512543, 0.4289420247077942, -0.17806565761566162, 1.5005273818969727, -0.3026750385761261, -0.131899893283844, 1.9318420886993408, 0.24965785443782806, -4.223690032958984, -1.5892119407653809, -0.9592061638832092, 0.6562575697898865, -1.9095708131790161, 0.5259149074554443, -2.035977602005005, 0.5248823761940002, -0.6465017795562744, -0.3960990011692047, -0.4112343490123749, -0.7429352402687073, 2.223327159881592, -0.4064072370529175, 0.5332739949226379, -2.303006887435913, -0.32963114976882935, 0.5295715928077698, -1.6657140254974365, -0.11833216995000839, 1.0787113904953003, -0.9311490654945374, 0.03704151138663292, -0.8894574642181396, 0.0859040766954422, -2.3014955520629883, -1.0067262649536133, 0.9859585762023926, 0.7782728672027588, -1.8216696977615356, -2.9927287101745605, 0.8131284713745117, 1.1510214805603027, 1.5506985187530518, -0.7995897531509399, -0.962861180305481, 0.03479010984301567, 0.39518147706985474, -0.8099024295806885, -1.4280505180358887, 1.3384819030761719, 0.7316527962684631, -1.6093990802764893, 1.122981071472168, -1.8624610900878906, -0.41842466592788696, -3.482168436050415, -0.4046655297279358, -2.658233880996704, 1.3364262580871582, -1.3522233963012695, -0.8652595281600952, 0.9860178828239441, 1.5346566438674927, 0.37899625301361084, -1.5254398584365845, -0.20887571573257446, 0.7720470428466797, -0.9673398733139038, 0.7413630485534668, 0.6068539023399353, -0.5225927233695984, -1.2624720335006714, -1.8790262937545776, -0.6126649975776672, 1.3079426288604736, -0.2752819359302521, 0.3728286027908325, 0.5163548588752747, 2.6142423152923584, 0.8896143436431885, -1.3314549922943115, -1.0803200006484985, 0.575139045715332, 0.43629834055900574, -0.5197871923446655, 0.43839505314826965, 3.789933443069458, -1.6344386339187622, -0.4556105434894562, -0.3167220652103424, 0.7454488277435303, 0.05425088852643967, 1.4139286279678345, -1.5970220565795898, -2.3960793018341064, -0.8282404541969299, -0.5367753505706787, -1.7410414218902588, -1.1188238859176636, -2.1776764392852783, 0.9133014678955078, -2.5429558753967285, -0.923439085483551, -0.49555912613868713, -0.7084755301475525, -1.7727042436599731, -1.3392421007156372, -2.0375659465789795, 2.0460145473480225, 2.0015079975128174, -0.14131611585617065, 1.2689597606658936, 1.0484029054641724, -0.7068841457366943, 1.2619155645370483, 1.8263866901397705, 0.3523692488670349, -2.1263115406036377, -1.2636137008666992, 0.050784166902303696, -0.08369031548500061, -0.9823043346405029, -1.3185195922851562, 8.892362594604492, 1.0706650018692017, -0.5322051644325256, -1.0136135816574097, 1.5819141864776611, 0.6579473614692688, 0.7654460072517395, -1.1410568952560425, 0.29072192311286926, -1.0253427028656006, 1.2966256141662598, -0.4298143684864044, -0.5606433749198914, 1.5416646003723145, -1.7555731534957886, -0.8866727948188782, -1.5599783658981323, 2.7274441719055176, 2.116166114807129, -1.4465495347976685, 0.04598298668861389, -1.4924381971359253, 1.1761192083358765, 0.8272542357444763, 0.4111374020 ...

# %% [markdown]
# ## Step 2: Retrieve
# Next, add the code to retrieve the most relevant document given an example prompt:

# %%
# an example prompt
prompt = "What animals are llamas related to?"

# generate an embedding for the prompt and retrieve the most relevant doc
response = ollama.embeddings(
  prompt=prompt,
  model="llama2"
)

results = collection.query.near_vector(near_vector=response["embedding"],
                             limit=1)

data = results.objects[0].properties['text']
print(data)
# Out:
# Llamas live to be about 20 years old, though some only live for 15 years and others live to be 30 years old

# %% [markdown]
# ## Step 3: Generate
# Lastly, use the prompt and the document retrieved in the previous step to generate an answer!

# %%
# generate a response combining the prompt and data we retrieved in step 2
output = ollama.generate(
  model="llama2",
  prompt=f"Using this data: {data}. Respond to this prompt: {prompt}"
)

print(output['response'])
# Out:
# {"action":"read_disk_use","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"warning","msg":"disk usage currently at 81.25%, threshold set to 80.00%","path":"/home/cdchushig/.local/share/weaviate","time":"2025-05-26T10:35:22+02:00"}
# Based on the provided data, we can infer that llamas have a relatively long lifespan compared to other animals in their family. Llamas are related to other even-toed ungulates, which includes:
#
# 1. Camels: Like llamas, camels also have a relatively long lifespan, with some individuals living up to 40 years in the wild.
# 2. Horses: Horses have a lifespan of around 25-30 years, which is shorter than that of llamas but longer than many other mammals.
# 3. Donkeys and Mules: These animals also belong to the even-toed ungulate family and have a similar lifespan to horses, typically ranging from 25 to 40 years.
# 4. Rhinoceroses: While not closely related to llamas, rhinoceroses are also even-toed ungulates with a typical lifespan of around 30-40 years.
#
# It's worth noting that the lifespan of these animals can vary depending on various factors such as diet, habitat, and health conditions.
# {"action":"read_disk_use","build_git_commit":"'\"$GITHASH\"'","build_go_version":"go1.22.0","build_image_tag":"localhost","build_wv_version":"1.26.6","level":"warning","msg":"disk usage currently at 81.25%, threshold set to 80.00%","path":"/home/cdchushig/.local/share/weaviate","time":"2025-05-26T10:45:23+02:00"}
